# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from plot import format_df

# %%
df = pd.read_csv("lidar_data.csv")
df = format_df(df)

# %%
df
# Out:
#      range  distance  signal_rate  ambient_light  spad_num  mot_angle  \
# 0        0       311        20336             32        32        0.7
# 1        0       311        20656             32        32        1.5
# 2        0       310        19992             24        31        2.2
# 3        0       312        20176             32        31        3.0
# 4        0       310        20496             24        31        3.7
# ..     ...       ...          ...            ...       ...        ...
# 475      0       398        20296             72        92      357.0
# 476      0       412        20328             72        93      357.7
# 477      0       424        19896             80        93      358.5
# 478      0       436        20104             96        95      359.2
# 479      0       445        20376             96        98        0.0
#
#      lap_num     angle           x          y  cuadrant
# 0          0  0.012217  310.976790   3.799487       1.0
# 1          0  0.026180  310.893428   8.141031       1.0
# 2          0  0.038397  309.771504  11.900221       1.0
# 3          0  0.052360  311.572415  16.328818       1.0
# 4          0  0.064577  309.353842  20.005016       1.0
# ..       ...       ...         ...        ...       ...
# 475        0  6.230825  397.454555 -20.829711       1.0
# 476        0  6.243043  411.668091 -16.534299       1.0
# 477        0  6.257005  423.854706 -11.099026       1.0
# 478        0  6.269223  435.957500  -6.087511       1.0
# 479        1  0.000000  445.000000   0.000000       1.0
#
# [480 rows x 11 columns]

# %%
import plotly.express as px

px.scatter_polar(df, r="distance", theta="mot_angle", color=df['lap_num'])

# %%
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(df["angle"], df["distance"])
